# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#Dataset
netflix_data=pd.read_csv(r'netflix.csv')
netflix_data.head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
#Dataset shape
netflix_data.shape
# Out:
# (8807, 12)

# %%
#Columns in datasetr
netflix_data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
netflix_data.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
netflix_data.describe(include='object').T
# Out:
#             count unique                                                top  \
# show_id      8807   8807                                                 s1
# type         8807      2                                              Movie
# title        8807   8807                               Dick Johnson Is Dead
# director     6173   4528                                      Rajiv Chilaka
# cast         7982   7692                                 David Attenborough
# country      7976    748                                      United States
# date_added   8797   1767                                    January 1, 2020
# rating       8803     17                                              TV-MA
# duration     8804    220                                           1 Season
# listed_in    8807    514                       Dramas, International Movies
# description  8807   8775  Paranormal activity at a lush, abandoned prope...
#
#              freq
# show_id         1
# ...

# %%
netflix_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
netflix_data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
netflix_data.nunique()
# Out:
# show_id         8807
# type               2
# title           8807
# director        4528
# cast            7692
# country          748
# date_added      1767
# release_year      74
# rating            17
# duration         220
# listed_in        514
# description     8775
# dtype: int64

# %%
netflix_data.shape
# Out:
# (8807, 12)

# %%
#creating a cop of dataframe and dropping null values
df=netflix_data.copy()
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
df.shape
# Out:
# (8807, 12)

# %%
df=df.dropna()
df.shape
# Out:
# (5332, 12)

# %%
df.head(2)
# Out:
#   show_id     type                          title         director  \
# 7      s8    Movie                        Sankofa     Haile Gerima
# 8      s9  TV Show  The Great British Baking Show  Andy Devonshire
#
#                                                 cast  \
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country          date_added  \
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                     United Kingdom  September 24, 2021
#
#    release_year rating   duration  \
# 7          1993  TV-MA    125 min
# 8          2021  TV-14  9 Seasons
#
#                                           listed_in  \
# 7  Dramas, Independent Movies, International Movies
# 8                      British TV Shows, Reality TV
#
#                                          description
# ...

# %%
df['type'].value_counts()
# Out:
# type
# Movie      5185
# TV Show     147
# Name: count, dtype: int64

# %%
netflix_data['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
df['director'].value_counts()
# Out:
# director
# Raúl Campos, Jan Suter           18
# Marcus Raboy                     15
# Jay Karas                        14
# Cathy Garcia-Molina              13
# Martin Scorsese                  12
#                                  ..
# Igor Kovalyov, Norton Virgien     1
# Danny Cannon                      1
# Mana Yasuda                       1
# Gupse Özay                        1
# Mozez Singh                       1
# Name: count, Length: 3945, dtype: int64

# %%
#Movies from a director
netflix_data['director'].value_counts()
# Out:
# director
# Rajiv Chilaka                     19
# Raúl Campos, Jan Suter            18
# Marcus Raboy                      16
# Suhas Kadav                       16
# Jay Karas                         14
#                                   ..
# Raymie Muzquiz, Stu Livingston     1
# Joe Menendez                       1
# Eric Bross                         1
# Will Eisenberg                     1
# Mozez Singh                        1
# Name: count, Length: 4528, dtype: int64

# %%
df[df['director']=='Rajiv Chilaka']
# Out:
#      show_id   type                                  title       director  \
# 410     s411  Movie     Chhota Bheem And The Broken Amulet  Rajiv Chilaka
# 415     s416  Movie               Chhota Bheem aur Krishna  Rajiv Chilaka
# 2717   s2718  Movie  Chhota Bheem and the Curse of Damyaan  Rajiv Chilaka
#
#                                                    cast country  \
# 410   Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...   India
# 415   Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...   India
# 2717  Kaustav Ghosh, Jigna Bhardwaj, Chutki, Rajesh ...   India
#
#          date_added  release_year rating duration                 listed_in  \
# 410   July 22, 2021          2013  TV-Y7   64 min  Children & Family Movies
# 415   July 22, 2021          2009  TV-Y7   68 min  Children & Family Movies
# 2717  April 1, 2020          2012  TV-Y7   87 min  Children & Family Movies
#
#                                             description
# ...

# %%
df[df['type']=='Movie']
# Out:
#      show_id   type         title             director  \
# 7         s8  Movie       Sankofa         Haile Gerima
# 9        s10  Movie  The Starling       Theodore Melfi
# 12       s13  Movie  Je Suis Karl  Christian Schwochow
# 24       s25  Movie         Jeans           S. Shankar
# 27       s28  Movie     Grown Ups         Dennis Dugan
# ...      ...    ...           ...                  ...
# 8801   s8802  Movie       Zinzana      Majid Al Ansari
# 8802   s8803  Movie        Zodiac        David Fincher
# 8804   s8805  Movie    Zombieland      Ruben Fleischer
# 8805   s8806  Movie          Zoom         Peter Hewitt
# 8806   s8807  Movie        Zubaan          Mozez Singh
#
#                                                    cast  \
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12    Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# ...

# %%
df['listed_in']
# Out:
# 7       Dramas, Independent Movies, International Movies
# 8                           British TV Shows, Reality TV
# 9                                       Comedies, Dramas
# 12                          Dramas, International Movies
# 24       Comedies, International Movies, Romantic Movies
#                               ...
# 8801             Dramas, International Movies, Thrillers
# 8802                      Cult Movies, Dramas, Thrillers
# 8804                             Comedies, Horror Movies
# 8805                  Children & Family Movies, Comedies
# 8806      Dramas, International Movies, Music & Musicals
# Name: listed_in, Length: 5332, dtype: object

# %%
#To display the individual genre
df['listed_in'].apply(lambda x:str(x).split(',')).to_list()
# Out:
# [['Dramas', ' Independent Movies', ' International Movies'],
#  ['British TV Shows', ' Reality TV'],
#  ['Comedies', ' Dramas'],
#  ['Dramas', ' International Movies'],
#  ['Comedies', ' International Movies', ' Romantic Movies'],
#  ['Comedies'],
#  ['Horror Movies', ' Sci-Fi & Fantasy'],
#  ['Thrillers'],
#  ['Action & Adventure', ' Dramas'],
#  ['Action & Adventure', ' Classic Movies', ' Dramas'],
#  ['Dramas', ' Horror Movies', ' Thrillers'],
#  ['Action & Adventure', ' Horror Movies', ' Thrillers'],
#  ['Action & Adventure', ' Horror Movies', ' Thrillers'],
#  ['Action & Adventure'],
#  ['Dramas', ' Thrillers'],
#  ['Action & Adventure', ' Anime Features', ' International Movies'],
#  ['Action & Adventure', ' Anime Features', ' International Movies'],
#  ['Action & Adventure', ' Anime Features', ' International Movies'],
#  ['Action & Adventure', ' Anime Features', ' International Movies'],
#  ['Action & Adventure', ' Anime Features', ' International Movies'],
# ...

# %%
#To determine genre for shows and movies
genre_list=df['listed_in'].apply(lambda x:str(x).split(',')).tolist()
genre=pd.DataFrame(genre_list,index=df['title'])

# %%
genre
# Out:
#                                                       0  \
# title
# Sankofa                                          Dramas
# The Great British Baking Show          British TV Shows
# The Starling                                   Comedies
# Je Suis Karl                                     Dramas
# Jeans                                          Comedies
# ...                                                 ...
# Zinzana                                          Dramas
# Zodiac                                      Cult Movies
# Zombieland                                     Comedies
# Zoom                           Children & Family Movies
# Zubaan                                           Dramas
#
#                                                    1                      2
# title
# Sankofa                           Independent Movies   International Movies
# The Great British Baking Show             Reality TV                   None
# ...

# %%
genre=genre.stack()
genre
# Out:
# title
# Sankofa                        0                      Dramas
#                                1          Independent Movies
#                                2        International Movies
# The Great British Baking Show  0            British TV Shows
#                                1                  Reality TV
#                                               ...
# Zoom                           0    Children & Family Movies
#                                1                    Comedies
# Zubaan                         0                      Dramas
#                                1        International Movies
#                                2            Music & Musicals
# Length: 11858, dtype: object

# %%
genre=pd.DataFrame(genre)
genre
# Out:
#                                                         0
# title
# Sankofa                       0                    Dramas
#                               1        Independent Movies
#                               2      International Movies
# The Great British Baking Show 0          British TV Shows
#                               1                Reality TV
# ...                                                   ...
# Zoom                          0  Children & Family Movies
#                               1                  Comedies
# Zubaan                        0                    Dramas
#                               1      International Movies
#                               2          Music & Musicals
#
# [11858 rows x 1 columns]

# %%
genre.reset_index(inplace=True)
genre=genre[['title',0]]
genre
# Out:
#                                title                         0
# 0                            Sankofa                    Dramas
# 1                            Sankofa        Independent Movies
# 2                            Sankofa      International Movies
# 3      The Great British Baking Show          British TV Shows
# 4      The Great British Baking Show                Reality TV
# ...                              ...                       ...
# 11853                           Zoom  Children & Family Movies
# 11854                           Zoom                  Comedies
# 11855                         Zubaan                    Dramas
# 11856                         Zubaan      International Movies
# 11857                         Zubaan          Music & Musicals
#
# [11858 rows x 2 columns]

# %%
genre.columns=['title','Genre']
genre
# Out:
#                                title                     Genre
# 0                            Sankofa                    Dramas
# 1                            Sankofa        Independent Movies
# 2                            Sankofa      International Movies
# 3      The Great British Baking Show          British TV Shows
# 4      The Great British Baking Show                Reality TV
# ...                              ...                       ...
# 11853                           Zoom  Children & Family Movies
# 11854                           Zoom                  Comedies
# 11855                         Zubaan                    Dramas
# 11856                         Zubaan      International Movies
# 11857                         Zubaan          Music & Musicals
#
# [11858 rows x 2 columns]

# %%
genre
# Out:
#                                title                     Genre
# 0                            Sankofa                    Dramas
# 1                            Sankofa        Independent Movies
# 2                            Sankofa      International Movies
# 3      The Great British Baking Show          British TV Shows
# 4      The Great British Baking Show                Reality TV
# ...                              ...                       ...
# 11853                           Zoom  Children & Family Movies
# 11854                           Zoom                  Comedies
# 11855                         Zubaan                    Dramas
# 11856                         Zubaan      International Movies
# 11857                         Zubaan          Music & Musicals
#
# [11858 rows x 2 columns]

# %%
#To display movie of specfic genre
genre[genre['Genre']=='Comedies']
# Out:
#                            title     Genre
# 5                   The Starling  Comedies
# 9                          Jeans  Comedies
# 12                     Grown Ups  Comedies
# 91                        Dhanak  Comedies
# 128                  House Party  Comedies
# ...                          ...       ...
# 11821  You Can’t Fight Christmas  Comedies
# 11825        You Changed My Life  Comedies
# 11830                Young Adult  Comedies
# 11840                   Zed Plus  Comedies
# 11851                 Zombieland  Comedies
#
# [1127 rows x 2 columns]

# %%
#To determine cast of given show
df['cast']
# Out:
# 7       Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8       Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9       Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12      Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24      Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
#                               ...
# 8801    Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
# 8802    Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8804    Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# Name: cast, Length: 5332, dtype: object

# %%
cast_of_show=df['cast'].apply(lambda x: str(x).split(',')).tolist()
cast_of_show
# Out:
# [['Kofi Ghanaba',
#   ' Oyafunmike Ogunlano',
#   ' Alexandra Duah',
#   ' Nick Medley',
#   ' Mutabaruka',
#   ' Afemo Omilami',
#   ' Reggie Carter',
#   ' Mzuri'],
#  ['Mel Giedroyc', ' Sue Perkins', ' Mary Berry', ' Paul Hollywood'],
#  ['Melissa McCarthy',
#   " Chris O'Dowd",
#   ' Kevin Kline',
#   ' Timothy Olyphant',
#   ' Daveed Diggs',
#   ' Skyler Gisondo',
#   ' Laura Harrier',
#   ' Rosalind Chao',
#   ' Kimberly Quinn',
#   ' Loretta Devine',
#   ' Ravi Kapoor'],
#  ['Luna Wedler',
#   ' Jannis Niewöhner',
#   ' Milan Peschel',
#   ' Edin Hasanović',
#   ' Anna Fialová',
#   ' Marlon Boess',
#   ' Victor Boccard',
#   ' Fleur Geffrier',
#   ' Aziz Dyab',
#   ' Mélanie Fouché',
#   ' Elizaveta Maximová'],
#  ['Prashanth', ' Aishwarya Rai Bachchan', ' Sri Lakshmi', ' Nassar'],
#  ['Adam Sandler',
#   ' Kevin James',
#   ' Chris Rock',
#   ' David Spade',
#   ' Rob Schneider',
#   ' Salma Hayek',
#   ' Maria Bello',
#   ' Maya Rudolph',
#   ' Colin Quinn',
# ...

# %%
cast=pd.DataFrame(cast_of_show,index=df['title'])
cast
# Out:
#                                              0                        1   \
# title
# Sankofa                            Kofi Ghanaba      Oyafunmike Ogunlano
# The Great British Baking Show      Mel Giedroyc              Sue Perkins
# The Starling                   Melissa McCarthy             Chris O'Dowd
# Je Suis Karl                        Luna Wedler         Jannis Niewöhner
# Jeans                                 Prashanth   Aishwarya Rai Bachchan
# ...                                         ...                      ...
# Zinzana                             Ali Suliman              Saleh Bakri
# Zodiac                             Mark Ruffalo          Jake Gyllenhaal
# Zombieland                      Jesse Eisenberg          Woody Harrelson
# Zoom                                  Tim Allen            Courteney Cox
# Zubaan                            Vicky Kaushal          Sarah-Jane Dias
#
#                                                2                  3   \
# title
# ...

# %%
df=df.stack()
df
# Out:
# 7     show_id                                                        s8
#       type                                                        Movie
#       title                                                     Sankofa
#       director                                             Haile Gerima
#       cast            Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
#                                             ...
# 8806  release_year                                                 2015
#       rating                                                      TV-14
#       duration                                                  111 min
#       listed_in          Dramas, International Movies, Music & Musicals
#       description     A scrappy but poor boy worms his way into a ty...
# Length: 63984, dtype: object

# %%
df=pd.DataFrame(df)
df
# Out:
#                                                                    0
# 7    show_id                                                      s8
#      type                                                      Movie
#      title                                                   Sankofa
#      director                                           Haile Gerima
#      cast          Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# ...                                                              ...
# 8806 release_year                                               2015
#      rating                                                    TV-14
#      duration                                                111 min
#      listed_in        Dramas, International Movies, Music & Musicals
#      description   A scrappy but poor boy worms his way into a ty...
#
# [63984 rows x 1 columns]

# %%
df=df.reset_index(inplace=True)
df

# %%
df=df[['title',0]]
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[145], line 1
# ----> 1 df=df[['title',0]]
#       2 df
#
# TypeError: 'NoneType' object is not subscriptable

# %%
df=df.columns=['title','cast']
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[146], line 1
# ----> 1 df=df.columns=['title','cast']
#       2 df
#
# AttributeError: 'list' object has no attribute 'columns'
